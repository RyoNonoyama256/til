# %%
# !pwd
# Out:
# /

# %%
import pandas as pd 

customer_master = pd.read_csv('/workdir/customer_master_min.csv')
customer_master.head()
# Out:
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1    TS808488         田村 詩織  2019-01-01 01:13:45            たむら しおり
# 2    AS834628         久野 由樹  2019-01-01 02:00:14             ひさの ゆき
# 3    AS345469          鶴岡 薫  2019-01-01 04:48:22           つるおか かおる
# 4    GD892565         大内 高史  2019-01-01 04:54:51           おおうち たかし
#
#                          email gender  age      birth pref
# 0  hirata_yuujirou@example.com      M   29  1990/6/10  石川県
# 1    tamura_shiori@example.com      F   33  1986/5/20  東京都
# 2      hisano_yuki@example.com      F   63   1956/1/2  茨城県
# 3   tsuruoka_kaoru@example.com      M   74  1945/3/25  東京都
# 4   oouchi_takashi@example.com      M   54   1965/8/5  千葉県

# %%
type(customer_master)
# Out:
# pandas.core.frame.DataFrame

# %%
customer_master.loc[0, :]
# Out:
# customer_id                              IK152942
# customer_name                              平田 裕次郎
# registration_date             2019-01-01 00:25:33
# customer_name_kana                      ひらた ゆうじろう
# email                 hirata_yuujirou@example.com
# gender                                          M
# age                                            29
# birth                                   1990/6/10
# pref                                          石川県
# Name: 0, dtype: object

# %%
customer_master.loc[:5, 'pref']
# Out:
# 0    石川県
# 1    東京都
# 2    茨城県
# 3    東京都
# 4    千葉県
# 5    岡山県
# Name: pref, dtype: object

# %%
customer_master.iloc[:10:2, [1, 4, 5]]
# Out:
#   customer_name                          email gender
# 0        平田 裕次郎    hirata_yuujirou@example.com      M
# 2         久野 由樹        hisano_yuki@example.com      F
# 4         大内 高史     oouchi_takashi@example.com      M
# 6         橋口 将也  hashiguchi_masaya@example.com      M
# 8        塩見 はるか      shiomi_haruka@example.com      F

# %%
customer_master = customer_master.loc[:99, :]
customer_master
# Out:
#    customer_id customer_name    registration_date customer_name_kana  \
# 0     IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1     TS808488         田村 詩織  2019-01-01 01:13:45            たむら しおり
# 2     AS834628         久野 由樹  2019-01-01 02:00:14             ひさの ゆき
# 3     AS345469          鶴岡 薫  2019-01-01 04:48:22           つるおか かおる
# 4     GD892565         大内 高史  2019-01-01 04:54:51           おおうち たかし
# ..         ...           ...                  ...                ...
# 95    PL417753          尾崎 勤  2019-01-05 10:14:25            おざき つとむ
# 96    PL964421          古沢 徹  2019-01-05 11:38:34           ふるさわ とおる
# 97    HI484575        八田 浩太郎  2019-01-05 12:39:04          やつだ こうたろう
# 98    GD903830        安藤 さやか  2019-01-05 12:39:22           あんどう さやか
# 99    PL683089         香川 美紀  2019-01-05 14:06:51             かがわ みき
#
#                            email gender  age      birth pref
# 0    hirata_yuujirou@example.com      M   29  1990/6/10  石川県
# ...
